# %% [markdown]
# > **Necessary Data**

# %%
record = {
    1 : { "item": "Wheat", "price": 30, "date": "03-08-2021", "inStock": True, "offer": 10 },
    2 : { "item": "Rice", "price": 90, "date": "06-07-2021","inStock": True , "offer": 0 },
    3 : { "item": "Barley", "price": 15, "date": "01-09-2021", "inStock": True, "offer": 20 },
    4 : { "item": "Milk", "price" :30, "date": "03-09-2021", "inStock": False, "offer": 18 },
    5 : { "item": "Kitkat", "price": 25, "date": "29-08-2021", "inStock": True, "offer": 15 },
    6 : { "item": "Maggi", "price": 12, "date": "20-08-2021", "inStock": True, "offer": 0 },
    7 : { "item": "Butter", "price": 50, "date": "31-08-2021", "inStock": True, "offer": 10 },
    8 : { "item": "Popcorn", "price": 250, "date": "15-08-2021", "inStock": True, "offer": 18 },
    9 : { "item": "Oats", "price": 99, "date": "05-08-2021", "inStock": True, "offer": 33 },
    10 : { "item": "Papads", "price": 20, "date": "24-08-2021", "inStock": True, "offer": 0 },
    11 : { "item": "Eggs", "price": 60, "date": "30-08-2021", "inStock": True, "offer": 0 },
    12 : { "item": "Pizza", "price": 180, "date": "02-09-2021", "inStock": True, "offer": 20 },
    13 : { "item": "Chips", "price": 185, "date": "20-08-2021", "inStock": False, "offer": 20 },
    14 : { "item": "Pepper", "price": 80, "date": "31-08-2021", "inStock": True, "offer": 0 },
    15 : { "item": "Cookies", "price": 30, "date": "17-08-2021", "inStock": True, "offer": 5 },
    16 : { "item": "Nuts", "price": 58, "date": "07-08-2021", "inStock": True, "offer": 15 },
    17 : { "item": "Sugar", "price": 55, "date": "05-06-2021", "inStock": True, "offer": 23 },
    18 : { "item": "Ice Cream", "price": 600, "date": "24-05-2021", "inStock": True, "offer": 30 },
    19 : { "item": "Bread", "price": 320, "date": "06-08-2021", "inStock": True, "offer": 15 },
    20 : { "item": "Cheese", "price": 680, "date": "08-04-2021", "inStock": False, "offer": 35 },
    21 : { "item": "Soda", "price": 60, "date": "01-09-2021", "inStock": True, "offer": 0 },
    22 : { "item": "Cakes", "price": 550, "date": "29-08-2021", "inStock": True, "offer": 20 },
    23 : { "item": "Lays", "price": 20, "date": "27-08-2021", "inStock": True, "offer": 0 },
    24 : { "item": "Coffee Powder", "price": 56, "date": "24-07-2021", "inStock": True, "offer": 18 },
    25 : { "item": "Salt", "price": 30, "date": "24-02-2021", "inStock": True, "offer": 0 },
    26 : { "item": "Ketchup", "price": 100, "date": "25-08-2021", "inStock": True, "offer": 0 },
    27 : { "item": "Juice", "price": 360, "date": "24-07-2021", "inStock": True, "offer": 0 },
    28 : { "item": "Candy", "price": 89, "date": "20-08-2021", "inStock": True, "offer": 13 },
    29 : { "item": "Buns", "price": 49, "date": "30-07-2021", "inStock": True, "offer": 15 },
    30 : { "item": "Brown Rice", "price": 1200, "date": "24-02-2021", "inStock": True, "offer": 20 }
}

# %%
# print("Unique ID\t", "Item Name\t" ,"Price\t", "Manufacture Date\t", "Available in stock\t", "Offer\t")
for i in record:
  # print(i, "\t\t", record[i]["item"], "\t\t", record[i]["price"], "\t\t", record[i]["date"], "\t\t", record[i]["inStock"], "\t\t", record[i]["offer"])
  print(i," = ",record[i])
# Out:
# 1  =  {'item': 'Wheat', 'price': 30, 'date': '03-08-2021', 'inStock': True, 'offer': 10}
# 2  =  {'item': 'Rice', 'price': 90, 'date': '06-07-2021', 'inStock': True, 'offer': 0}
# 3  =  {'item': 'Barley', 'price': 15, 'date': '01-09-2021', 'inStock': True, 'offer': 20}
# 4  =  {'item': 'Milk', 'price': 30, 'date': '03-09-2021', 'inStock': False, 'offer': 18}
# 5  =  {'item': 'Kitkat', 'price': 25, 'date': '29-08-2021', 'inStock': True, 'offer': 15}
# 6  =  {'item': 'Maggi', 'price': 12, 'date': '20-08-2021', 'inStock': True, 'offer': 0}
# 7  =  {'item': 'Butter', 'price': 50, 'date': '31-08-2021', 'inStock': True, 'offer': 10}
# 8  =  {'item': 'Popcorn', 'price': 250, 'date': '15-08-2021', 'inStock': True, 'offer': 18}
# 9  =  {'item': 'Oats', 'price': 99, 'date': '05-08-2021', 'inStock': True, 'offer': 33}
# 10  =  {'item': 'Papads', 'price': 20, 'date': '24-08-2021', 'inStock': True, 'offer': 0}
# 11  =  {'item': 'Eggs', 'price': 60, 'date': '30-08-2021', 'inStock': True, 'offer': 0}
# 12  =  {'item': 'Pizza', 'price': 180, 'date': '02-09-2021', 'inStock': True, 'offer': 20}
# 13  =  {'item': 'Chips', 'price': 185, 'date': '20-08-2021', 'inStock': False, 'offer': 20}
# 14  =  {'item': 'Pepper', 'price': 80, 'date': '31-08-2021', 'inStock': True, 'offer': 0}
# 15  =  {'item': 'Cookies', 'price': 30, 'date': '17-08-2021', 'inStock': True, 'offer': 5}
# 16  =  {'item': 'Nuts', 'price': 58, 'date': '07-08-2021', 'inStock': True, 'offer': 15}
# 17  =  {'item': 'Sugar', 'price': 55, 'date': '05-06-2021', 'inStock': True, 'offer': 23}
# 18  =  {'item': 'Ice Cream', 'price': 600, 'date': '24-05-2021', 'inStock': True, 'offer': 30}
# 19  =  {'item': 'Bread', 'price': 320, 'date': '06-08-2021', 'inStock': True, 'offer': 15}
# 20  =  {'item': 'Cheese', 'price': 680, 'date': '08-04-2021', 'inStock': False, 'offer': 35}
# 21  =  {'item': 'Soda', 'price': 60, 'date': '01-09-2021', 'inStock': True, 'offer': 0}
# 22  =  {'item': 'Cakes', 'price': 550, 'date': '29-08-2021', 'inStock': True, 'offer': 20}
# 23  =  {'item': 'Lays', 'price': 20, 'date': '27-08-2021', 'inStock': True, 'offer': 0}
# 24  =  {'item': 'Coffee Powder', 'price': 56, 'date': '24-07-2021', 'inStock': True, 'offer': 18}
# 25  =  {'item': 'Salt', 'price': 30, 'date': '24-02-2021', 'inStock': True, 'offer': 0}
# 26  =  {'item': 'Ketchup', 'price': 100, 'date': '25-08-2021', 'inStock': True, 'offer': 0}
# 27  =  {'item': 'Juice', 'price': 360, 'date': '24-07-2021', 'inStock': True, 'offer': 0}
# 28  =  {'item': 'Candy', 'price': 89, 'date': '20-08-2021', 'inStock': True, 'offer': 13}
# 29  =  {'item': 'Buns', 'price': 49, 'date': '30-07-2021', 'inStock': True, 'offer': 15}
# 30  =  {'item': 'Brown Rice', 'price': 1200, 'date': '24-02-2021', 'inStock': True, 'offer': 20}

# %%
import json

# %%
js = json.dumps(record)

# %%
js
# Out:
# '{"1": {"item": "Wheat", "price": 30, "date": "03-08-2021", "inStock": true, "offer": 10}, "2": {"item": "Rice", "price": 90, "date": "06-07-2021", "inStock": true, "offer": 0}, "3": {"item": "Barley", "price": 15, "date": "01-09-2021", "inStock": true, "offer": 20}, "4": {"item": "Milk", "price": 30, "date": "03-09-2021", "inStock": false, "offer": 18}, "5": {"item": "Kitkat", "price": 25, "date": "29-08-2021", "inStock": true, "offer": 15}, "6": {"item": "Maggi", "price": 12, "date": "20-08-2021", "inStock": true, "offer": 0}, "7": {"item": "Butter", "price": 50, "date": "31-08-2021", "inStock": true, "offer": 10}, "8": {"item": "Popcorn", "price": 250, "date": "15-08-2021", "inStock": true, "offer": 18}, "9": {"item": "Oats", "price": 99, "date": "05-08-2021", "inStock": true, "offer": 33}, "10": {"item": "Papads", "price": 20, "date": "24-08-2021", "inStock": true, "offer": 0}, "11": {"item": "Eggs", "price": 60, "date": "30-08-2021", "inStock": true, "offer": 0}, "12": {"item": "Pizza", "price": 180, "date": "02-09-2021", "inStock": true, "offer": 20}, "13": {"item": "Chips", "price": 185, "date": "20-08-2021", "inStock": false, "offer": 20}, "14": {"item": "Pepper", "price": 80, "date": "31-08-2021", "inStock": true, "offer": 0}, "15": {"item": "Cookies", "price": 30, "date": "17-08-2021", "inStock": true, "offer": 5}, "16": {"item": "Nuts", "price": 58, "date": "07-08-2021", "inStock": true, "offer": 15}, "17": {"item": "Sugar", "price": 55, "date": "05-06-2021", "inStock": true, "offer": 23}, "18": {"item": "Ice Cream", "price": 600, "date": "24-05-2021", "inStock": true, "offer": 30}, "19": {"item": "Bread", "price": 320, "date": "06-08-2021", "inStock": true, "offer": 15}, "20": {"item": "Cheese", "price": 680, "date": "08-04-2021", "inStock": false, "offer": 35}, "21": {"item": "Soda", "price": 60, "date": "01-09-2021", "inStock": true, "offer": 0}, "22": {"item": "Cakes", "price": 550, "date": "29-08-2021", "inStock": true, "offer": 20}, "23": {"item": "Lays", "price": 20, "date": "27-08-2021", "inStock": true, "offer": 0}, "24": {"item": "Coffee Powder", "price": 56, "date": "24-07-2021", "inStock": true, "offer": 18}, "25": {"item": "Salt", "price": 30, "date": "24-02-2021", "inStock": true, "offer": 0}, "26": {"item": "Ketchup", "price": 100, "date": "25-08-2021", "inStock": true, "offer": 0}, "27": {"item": "Juice", "price": 360, "date": "24-07-2021", "inStock": true, "offer": 0}, "28": {"item": "Candy", "price": 89, "date": "20-08-2021", "inStock": true, "offer": 13}, "29": {"item": "Buns", "price": 49, "date": "30-07-2021", "inStock": true, "offer": 15}, "30": {"item": "Brown Rice", "price": 1200, "date": "24-02-2021", "inStock": true, "offer": 20}}'

# %%
daily_count = 0
fd = open("record.json","w")
fd.write(js)
fd.close()

# %%
fd = open("record.json","r")
txt = fd.read()
fd.close()

# %%
txt
# Out:
# '{"1": {"item": "Wheat", "price": 30, "date": "03-08-2021", "inStock": true, "offer": 10}, "2": {"item": "Rice", "price": 90, "date": "06-07-2021", "inStock": true, "offer": 0}, "3": {"item": "Barley", "price": 15, "date": "01-09-2021", "inStock": true, "offer": 20}, "4": {"item": "Milk", "price": 30, "date": "03-09-2021", "inStock": false, "offer": 18}, "5": {"item": "Kitkat", "price": 25, "date": "29-08-2021", "inStock": true, "offer": 15}, "6": {"item": "Maggi", "price": 12, "date": "20-08-2021", "inStock": true, "offer": 0}, "7": {"item": "Butter", "price": 50, "date": "31-08-2021", "inStock": true, "offer": 10}, "8": {"item": "Popcorn", "price": 250, "date": "15-08-2021", "inStock": true, "offer": 18}, "9": {"item": "Oats", "price": 99, "date": "05-08-2021", "inStock": true, "offer": 33}, "10": {"item": "Papads", "price": 20, "date": "24-08-2021", "inStock": true, "offer": 0}, "11": {"item": "Eggs", "price": 60, "date": "30-08-2021", "inStock": true, "offer": 0}, "12": {"item": "Pizza", "price": 180, "date": "02-09-2021", "inStock": true, "offer": 20}, "13": {"item": "Chips", "price": 185, "date": "20-08-2021", "inStock": false, "offer": 20}, "14": {"item": "Pepper", "price": 80, "date": "31-08-2021", "inStock": true, "offer": 0}, "15": {"item": "Cookies", "price": 30, "date": "17-08-2021", "inStock": true, "offer": 5}, "16": {"item": "Nuts", "price": 58, "date": "07-08-2021", "inStock": true, "offer": 15}, "17": {"item": "Sugar", "price": 55, "date": "05-06-2021", "inStock": true, "offer": 23}, "18": {"item": "Ice Cream", "price": 600, "date": "24-05-2021", "inStock": true, "offer": 30}, "19": {"item": "Bread", "price": 320, "date": "06-08-2021", "inStock": true, "offer": 15}, "20": {"item": "Cheese", "price": 680, "date": "08-04-2021", "inStock": false, "offer": 35}, "21": {"item": "Soda", "price": 60, "date": "01-09-2021", "inStock": true, "offer": 0}, "22": {"item": "Cakes", "price": 550, "date": "29-08-2021", "inStock": true, "offer": 20}, "23": {"item": "Lays", "price": 20, "date": "27-08-2021", "inStock": true, "offer": 0}, "24": {"item": "Coffee Powder", "price": 56, "date": "24-07-2021", "inStock": true, "offer": 18}, "25": {"item": "Salt", "price": 30, "date": "24-02-2021", "inStock": true, "offer": 0}, "26": {"item": "Ketchup", "price": 100, "date": "25-08-2021", "inStock": true, "offer": 0}, "27": {"item": "Juice", "price": 360, "date": "24-07-2021", "inStock": true, "offer": 0}, "28": {"item": "Candy", "price": 89, "date": "20-08-2021", "inStock": true, "offer": 13}, "29": {"item": "Buns", "price": 49, "date": "30-07-2021", "inStock": true, "offer": 15}, "30": {"item": "Brown Rice", "price": 1200, "date": "24-02-2021", "inStock": true, "offer": 20}}'

# %% [markdown]
# **JSON to Dictionary**

# %%
js_to_dict = json.loads(txt)

# %%
js_to_dict
# Out:
# {'1': {'date': '03-08-2021',
#   'inStock': True,
#   'item': 'Wheat',
#   'offer': 10,
#   'price': 30},
#  '10': {'date': '24-08-2021',
#   'inStock': True,
#   'item': 'Papads',
#   'offer': 0,
#   'price': 20},
#  '11': {'date': '30-08-2021',
#   'inStock': True,
#   'item': 'Eggs',
#   'offer': 0,
#   'price': 60},
#  '12': {'date': '02-09-2021',
#   'inStock': True,
#   'item': 'Pizza',
#   'offer': 20,
#   'price': 180},
#  '13': {'date': '20-08-2021',
#   'inStock': False,
#   'item': 'Chips',
#   'offer': 20,
#   'price': 185},
#  '14': {'date': '31-08-2021',
#   'inStock': True,
#   'item': 'Pepper',
#   'offer': 0,
#   'price': 80},
#  '15': {'date': '17-08-2021',
#   'inStock': True,
#   'item': 'Cookies',
#   'offer': 5,
#   'price': 30},
#  '16': {'date': '07-08-2021',
#   'inStock': True,
#   'item': 'Nuts',
#   'offer': 15,
#   'price': 58},
#  '17': {'date': '05-06-2021',
#   'inStock': True,
#   'item': 'Sugar',
#   'offer': 23,
#   'price': 55},
#  '18': {'date': '24-05-2021',
#   'inStock': True,
#   'item': 'Ice Cream',
#   'offer': 30,
#   'price': 600},
#  '19': {'date': '06-08-2021',
#   'inStock': True,
#   'item': 'Bread',
#   'offer': 15,
#   'price': 320},
#  '2': {'date': '06-07-2021',
#   'inStock': True,
#   'item': 'Rice',
#   'offer': 0,
#   'price': 90},
#  '20': {'date': '08-04-2021',
#   'inStock': False,
#   'item': 'Cheese',
#   'offer': 35,
#   'price': 680},
#  '21': {'date': '01-09-2021',
#   'inStock': True,
#   'item': 'Soda',
#   'offer': 0,
#   'price': 60},
#  '22': {'date': '29-08-2021',
#   'inStock': True,
#   'item': 'Cakes',
#   'offer': 20,
#   'price': 550},
#  '23': {'date': '27-08-2021',
#   'inStock': True,
#   'item': 'Lays',
#   'offer': 0,
#   'price': 20},
#  '24': {'date': '24-07-2021',
#   'inStock': True,
#   'item': 'Coffee Powder',
#   'offer': 18,
#   'price': 56},
#  '25': {'date': '24-02-2021',
#   'inStock': True,
#   'item': 'Salt',
#   'offer': 0,
#   'price': 30},
#  '26': {'date': '25-08-2021',
#   'inStock': True,
#   'item': 'Ketchup',
#   'offer': 0,
#   'price': 100},
#  '27': {'date': '24-07-2021',
#   'inStock': True,
#   'item': 'Juice',
#   'offer': 0,
#   'price': 360},
#  '28': {'date': '20-08-2021',
#   'inStock': True,
#   'item': 'Candy',
#   'offer': 13,
#   'price': 89},
#  '29': {'date': '30-07-2021',
#   'inStock': True,
#   'item': 'Buns',
#   'offer': 15,
#   'price': 49},
#  '3': {'date': '01-09-2021',
#   'inStock': True,
#   'item': 'Barley',
#   'offer': 20,
#   'price': 15},
#  '30': {'date': '24-02-2021',
#   'inStock': True,
#   'item': 'Brown Rice',
#   'offer': 20,
#   'price': 1200},
#  '4': {'date': '03-09-2021',
#   'inStock': False,
#   'item': 'Milk',
#   'offer': 18,
#   'price': 30},
#  '5': {'date': '29-08-2021',
#   'inStock': True,
#   'item': 'Kitkat',
#   'offer': 15,
#   'price': 25},
#  '6': {'date': '20-08-2021',
#   'inStock': True,
#   'item': 'Maggi',
#   'offer': 0,
#   'price': 12},
#  '7': {'date': '31-08-2021',
#   'inStock': True,
#   'item': 'Butter',
#   'offer': 10,
#   'price': 50},
#  '8': {'date': '15-08-2021',
#   'inStock': True,
#   'item': 'Popcorn',
#   'offer': 18,
#   'price': 250},
#  '9': {'date': '05-08-2021',
#   'inStock': True,
#   'item': 'Oats',
#   'offer': 33,
#   'price': 99}}

# %%
type(js_to_dict)
# Out:
# dict

# %% [markdown]
# **Inventory Management System**

# %%
print("Welcome to SUPER MARKET")
# Out:
# Welcome to SUPER MARKET

# %%
print("\t||Unique ID\t||", "Item Name\t\t\t", "||" ,"Price\t", "\t\t||Manufacture Date", "\t||Available in stock", "\t ||Offer")
print('-*'*75)
for i in record:
  print("\t||", i, "\t\t||", record[i]["item"],(28-len(record[i]["item"]))*" ", "||", record[i]["price"], (18-len(record[i]["date"]))*" ","\t\t||", record[i]["date"], "\t\t","||", record[i]["inStock"], "\t\t", "||", record[i]["offer"])
# Out:
# 	||Unique ID	|| Item Name			 || Price	 		||Manufacture Date 	||Available in stock 	 ||Offer
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*
# 	|| 1 		|| Wheat                         || 30          		|| 03-08-2021 		 || True 		 || 10
# 	|| 2 		|| Rice                          || 90          		|| 06-07-2021 		 || True 		 || 0
# 	|| 3 		|| Barley                        || 15          		|| 01-09-2021 		 || True 		 || 20
# 	|| 4 		|| Milk                          || 30          		|| 03-09-2021 		 || False 		 || 18
# 	|| 5 		|| Kitkat                        || 25          		|| 29-08-2021 		 || True 		 || 15
# 	|| 6 		|| Maggi                         || 12          		|| 20-08-2021 		 || True 		 || 0
# 	|| 7 		|| Butter                        || 50          		|| 31-08-2021 		 || True 		 || 10
# 	|| 8 		|| Popcorn                       || 250          		|| 15-08-2021 		 || True 		 || 18
# 	|| 9 		|| Oats                          || 99          		|| 05-08-2021 		 || True 		 || 33
# 	|| 10 		|| Papads                        || 20          		|| 24-08-2021 		 || True 		 || 0
# 	|| 11 		|| Eggs                          || 60          		|| 30-08-2021 		 || True 		 || 0
# 	|| 12 		|| Pizza                         || 180          		|| 02-09-2021 		 || True 		 || 20
# 	|| 13 		|| Chips                         || 185          		|| 20-08-2021 		 || False 		 || 20
# 	|| 14 		|| Pepper                        || 80          		|| 31-08-2021 		 || True 		 || 0
# 	|| 15 		|| Cookies                       || 30          		|| 17-08-2021 		 || True 		 || 5
# 	|| 16 		|| Nuts                          || 58          		|| 07-08-2021 		 || True 		 || 15
# 	|| 17 		|| Sugar                         || 55          		|| 05-06-2021 		 || True 		 || 23
# 	|| 18 		|| Ice Cream                     || 600          		|| 24-05-2021 		 || True 		 || 30
# 	|| 19 		|| Bread                         || 320          		|| 06-08-2021 		 || True 		 || 15
# 	|| 20 		|| Cheese                        || 680          		|| 08-04-2021 		 || False 		 || 35
# 	|| 21 		|| Soda                          || 60          		|| 01-09-2021 		 || True 		 || 0
# 	|| 22 		|| Cakes                         || 550          		|| 29-08-2021 		 || True 		 || 20
# 	|| 23 		|| Lays                          || 20          		|| 27-08-2021 		 || True 		 || 0
# 	|| 24 		|| Coffee Powder                 || 56          		|| 24-07-2021 		 || True 		 || 18
# 	|| 25 		|| Salt                          || 30          		|| 24-02-2021 		 || True 		 || 0
# 	|| 26 		|| Ketchup                       || 100          		|| 25-08-2021 		 || True 		 || 0
# 	|| 27 		|| Juice                         || 360          		|| 24-07-2021 		 || True 		 || 0
# 	|| 28 		|| Candy                         || 89          		|| 20-08-2021 		 || True 		 || 13
# 	|| 29 		|| Buns                          || 49          		|| 30-07-2021 		 || True 		 || 15
# 	|| 30 		|| Brown Rice                    || 1200          		|| 24-02-2021 		 || True 		 || 20

# %%
f = open("sales.json","a")
will_buy = True
print("Welcome To Grocery Shop")
while will_buy:
  n = int(input("Dear Customer, Please Enter Unique Id of the product that you want to buy: "))
  q = int(input("Dear Customer, Enter the quantity of the product: "))
  daily_count += q
  f.write(str(record[n])+"\nTotal Price = "+str(record[n]["price"]*q))
  print("Dear Customer, Press 1 to continue else press any key to quit")
  n = input("Dear Customer, Enter your option: ")
  will_buy = True if n == '1'  else False

f.write("\nProducts saled upto now = "+str(daily_count)+"\n")
f.close()
# Out:
# Welcome To Grocery Shop
# Dear Customer, Please Enter Unique Id of the product that you want to buy: 1
# Dear Customer, Enter the quantity of the product: 2
# Dear Customer, Press 1 to continue else press any key to quit
# Dear Customer, Enter your option: 0

# %%
f = open("sales.json","r")
text = f.read()
f.close()

# %%
text
# Out:
# "{'item': 'Wheat', 'price': 30, 'date': '03-08-2021', 'inStock': True, 'offer': 10}\nTotal Price = 60\nProducts saled upto now = 2\n"
